# %%
print("Hello")
# Out:
# Hello

# %%
# shift+enter button together we have to press ---# is used for commenting

# %%
# how to download the jupyter notebook :

# File ----> downloads ----> notebook.ipynb ext
